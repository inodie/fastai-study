# %%
#| default_exp cat_dog_find

# %% [markdown]
# # Core Fuctions
# > fastai를 이용해 개와 고양이를 분류합니다.

# %%
import torch
if torch.backends.mps.is_available():
    mps_device = torch.device("mps")
    print("MPS 장치를 사용할 수 있습니다.")
else:
    print("MPS 장치를 찾을 수 없습니다. CPU로 실행됩니다.")

# fastai Learner 생성 시 장치 지정 (보통 자동으로 잡히지만 명시하면 확실합니다)
# learn = vision_learner(dls, resnet34, metrics=error_rate).to('mps')
# Out:
# MPS 장치를 사용할 수 있습니다.

# %%
#| export
from fastai.vision.all import *

path = untar_data(URLs.PETS)/'images'

def is_cat(x): return x[0].isupper()
dls = ImageDataLoaders.from_name_func(
    path, get_image_files(path), valid_pct=0.2, seed=42,
    label_func=is_cat, item_tfms=Resize(224))

learn = vision_learner(dls, resnet34, metrics=error_rate)
learn.fine_tune(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 12
#       7 dls = ImageDataLoaders.from_name_func(
#       8     path, get_image_files(path), valid_pct=0.2, seed=42,
#       9     label_func=is_cat, item_tfms=Resize(224))
#      11 learn = vision_learner(dls, resnet34, metrics=error_rate).to('mps')
# ---> 12 learn.fine_tune(1)
#
# File ~/Desktop/fastai-study/fastai-study/fastai/lib/python3.12/site-packages/torch/nn/modules/module.py:1928, in Module.__getattr__(self, name)
#    1926     if name in modules:
#    1927         return modules[name]
# -> 1928 raise AttributeError(
#    1929     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1930 )
#
# AttributeError: 'Sequential' object has no attribute 'fine_tune'
