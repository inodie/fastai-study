# %%
#| default_exp cat dog find

# %% [markdown]
# # Core Fuctions
# > fastai를 이용해 개와 고양이를 분류합니다.

# %%
#| export
from fastai.vision.all import *

path = untar_data(URLs.PETS)/'images'

def is_cat(x): return x[0].isupper()
dls = ImageDataLoaders.from_name_func(
    path, get_image_files(path), valid_pct=0.2, seed=42,
    label_func=is_cat, item_tfms=Resize(224))

learn = vision_learner(dls, resnet34, metrics=error_rate)
learn.fine_tune(1)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 3
#       1 #| export
#       2 from fastai.vision.all import *
# ----> 3 from fastprogress import force_console
#       4 import fastprogress
#       6 fastprogress.fastprogress.printing = force_console
#
# ImportError: cannot import name 'force_console' from 'fastprogress' (/Users/leejaewon/Desktop/fastai-study/fastai-study/fastai/lib/python3.13/site-packages/fastprogress/__init__.py)
